# %% [markdown]
# <a href="https://colab.research.google.com/github/aastha1993/git_test/blob/master/Aastha_practice_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_countries=pd.read_csv("Countries_data.csv")

# %%
df_countries.describe()
# Out:
#        indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# count            177.000000          177.000000        175.000000
# mean               0.433633            0.271169          0.205794
# std                0.308818            0.255504          0.239538
# min                0.003000            0.010000          0.011000
# 25%                0.135000            0.102000          0.044500
# 50%                0.373000            0.169000          0.096000
# 75%                0.682000            0.322000          0.244000
# max                0.992000            0.905000          0.879000
#
#        Economic.Freedom.Summary.Index  Government.consumption  \
# count                      182.000000              182.000000
# mean                         5.497105                6.397742
# std                          0.990792                1.631789
# min                          3.400000                0.050000
# ...

# %%
df_grouped=df_countries.groupby('Regime_type')

# %%
df_Countries.groupby('Regime_type')['Size of Government'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a336890deb01> in <cell line: 1>()
# ----> 1 df_Countries.groupby('Regime_type')['Size of Government'].describe()
#
# NameError: name 'df_Countries' is not defined

# %%
df_countries['libdem_vdem_owid_nomiss']=df_countries['libdem_vdem_owid'].fillna(df_countries['libdem_vdem_owid'].mean())

# %%
df_countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 44 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
type(df_countries.iloc[3]['libdem_vdem_owid'])
# Out:
# numpy.float64

# %%
for i in range(0,182):
   if type(df_countries.iloc[1]['libdem_vdem_owid'])==str:
     print("I found a string")

# %%
data = {'price': [100, 200, 150, 300]}
df = pd.DataFrame(data)
# Apply a lambda function to calculate discounted price
df['new_price'] = df['price'].apply(lambda x: x * 0.9)

# %%
data = {'price': [100, 200, 150, 300]}
df = pd.DataFrame(data)
df['new_price']= df['price']*0.9

# %%
df.head()
# Out:
#    price  new_price
# 0    100       90.0
# 1    200      180.0
# 2    150      135.0
# 3    300      270.0

# %%
df.head()
# Out:
#    price  new_price
# 0    100       90.0
# 1    200      180.0
# 2    150      135.0
# 3    300      270.0

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
# Define the conditions and corresponding functions/logic
condition1 = df['A'] < 3
function1 = lambda x: x * 2
condition2 = df['A'] >= 3
function2 = lambda x: x + 5
# Apply the functions/logic based on conditions and create the new column
df['C'] = df['C'] = np.where(condition1, function1(df['B']), function2(df['B']))

print(df)
# Out:
#    A   B   C
# 0  1  10  20
# 1  2  20  40
# 2  3  30  35
# 3  4  40  45
# 4  5  50  55
